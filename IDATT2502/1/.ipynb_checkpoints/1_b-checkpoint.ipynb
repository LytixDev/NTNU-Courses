# %%
# !wget https://gitlab.com/ntnu-tdat3025/regression/childgrowth-datasets/raw/master/day_length_weight.csv
# Out:
# --2023-08-29 18:57:46--  https://gitlab.com/ntnu-tdat3025/regression/childgrowth-datasets/raw/master/day_length_weight.csv
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75020 (73K) [text/plain]
# Saving to: ‘day_length_weight.csv’
#
# day_length_weight.c 100%[===================>]  73.26K  --.-KB/s    in 0.01s
#
# 2023-08-29 18:57:47 (5.78 MB/s) - ‘day_length_weight.csv’ saved [75020/75020]

# %%
import torch
import matplotlib.pyplot as plt

# %%
with open("day_length_weight.csv") as f:
    data = [i.split(",") for i in f.readlines()]

days = [float(r[1]) for r in data[1:]]
lengths = [float(r[1]) for r in data[1:]]
weights = [float(r[2]) for r in data[1:]]

x_train = torch.tensor([[l, r] for l, r in zip(lengths, weights)]).reshape(-1, 2)
y_train = torch.tensor(days).reshape(-1, 1)

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(projection='3d')

# Scatter plot in 3D space
ax.scatter(days, lengths, weights, c='blue', marker='o', label='Data Points')
ax.set_xlabel('Day')
ax.set_ylabel('Length')
ax.set_zlabel('Weight')
ax.set_title('Day, Length, and Weight')
ax.legend()
plt.show()

# %%
class LinearRegressionModel3D:
    def __init__(self):
        # self.W = torch.tensor([[0, 0]], requires_grad=True).reshape(-1, 2)
        self.W = torch.rand((2, 1), requires_grad=True)
        self.b = torch.tensor([[0.0]], requires_grad=True)

    def f(self, x):
        return x @ self.W + self.b
        
    def loss(self, x, y):
        return torch.mean(torch.square(self.f(x) - y))  # Can also use torch.nn.functional.mse_loss(self.f(x), y) to possibly increase numberical stability

# %%
model = LinearRegressionModel3D()
optimizer = torch.optim.SGD([model.W, model.b], lr=0.0001)

epochs = 1_000_000
for epoch in range(epochs):
    if epoch % (epochs // 10)  == 0:
        print("Done:", epoch)
    model.loss(x_train, y_train).backward()
    optimizer.step()
    optimizer.zero_grad()

print("DONE !!!")
# Out:
# Done: 0
# Done: 100000
# Done: 200000
# Done: 300000
# Done: 400000
# Done: 500000
# Done: 600000
# Done: 700000
# Done: 800000
# Done: 900000
# DONE !!!

# %%
print("W = %s, b = %s, loss = %s" % (model.W, model.b, model.loss(x_train, y_train)))
# Out:
# W = tensor([[9.9998e-01],
#         [4.2608e-05]], requires_grad=True), b = tensor([[0.0011]], requires_grad=True), loss = tensor(2.1789e-08, grad_fn=<MeanBackward0>)

# %%
# Visualize result
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x_train[:, 0], x_train[:, 1], y_train[:, 0], label='Data')  # Adjusted for 2D input and 1D output

# Generate a grid of values for x and y, and compute the model's predictions
grid_size = 50
x_vals = torch.linspace(torch.min(x_train[:, 0]), torch.max(x_train[:, 0]), grid_size)
y_vals = torch.linspace(torch.min(x_train[:, 1]), torch.max(x_train[:, 1]), grid_size)
X, Y = torch.meshgrid(x_vals, y_vals)
combined_grid = torch.stack((X.reshape(-1), Y.reshape(-1)), dim=1)
predictions = model.f(combined_grid).detach().reshape(grid_size, grid_size)

ax.plot_wireframe(X, Y, predictions, color='green', label='Model Prediction')

ax.set_xlabel('vekt')
ax.set_ylabel('lenngde')
ax.set_zlabel('alder')
plt.legend()
plt.show()
# Out:
# /home/nic/School/maskinlæring/labs/1/venv/lib/python3.11/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
torch.rand((2, 1), requires_grad=True)

torch.tensor([[0, 0], [0, 0]]).reshape(-1, 2)
# Out:
# tensor([[0, 0],
#         [0, 0]])
